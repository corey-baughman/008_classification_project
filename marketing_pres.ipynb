# %% [markdown]
# ### Prep .csv to feed Tableau for Marketing Pres

# %%
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from math import sqrt
# to turn off pink warning boxes basically for display purposes in class
import warnings
warnings.filterwarnings('ignore')

# import splitting and imputing functions
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# classification algorithms
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# classification analysis
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# to see local file system
import os

# import our own modules
import env
import acquire as a
import prepare as p

# jupyter settings
# %matplotlib inline

# %%
# telco_tableau = p.telco_pre_split_clean(a.new_telco_data())
# telco_tableau.head().T
telco_tableau['solo_cust'] = ((telco_tableau.partner == 'No') & (telco_tableau.dependents == 'No'))

telco_tableau['no_cost_to_switch'] = ((telco_tableau.online_security == 'No') & (telco_tableau.online_backup == 'No'))

telco_tableau['pain_points'] = ((telco_tableau.tech_support == 'No') | 
                                (telco_tableau.paperless_billing == 'Yes') | 
                                (telco_tableau.payment_type == 'Electronic check'))

telco_tableau.to_csv('telco_tableau.csv')

# %%
telco_tableau.head()
# Out:
#   customer_id  gender senior_citizen partner dependents tenure phone_service  \
# 0  0002-ORFBO  Female              0     Yes        Yes      9           Yes
# 1  0003-MKNFE    Male              0      No         No      9           Yes
# 2  0004-TLHLJ    Male              0      No         No      4           Yes
# 3  0011-IGKFF    Male              1     Yes         No     13           Yes
# 4  0013-EXCHZ  Female              1     Yes         No      3           Yes
#
#   multiple_lines online_security online_backup  ... paperless_billing  \
# 0             No              No           Yes  ...               Yes
# 1            Yes              No            No  ...                No
# 2             No              No            No  ...               Yes
# 3             No              No           Yes  ...               Yes
# 4             No              No            No  ...               Yes
#
#   monthly_charges total_charges churn internet_service_type   contract_type  \
# ...

# %%
telco_tableau.solo_cust.value_counts(normalize=True)
# Out:
# False    0.534289
# True     0.465711
# Name: solo_cust, dtype: float64
